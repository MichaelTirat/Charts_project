# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# # import datasets :

# %%
lyricspath = r"C:\Users\micha\PycharmProjects\Charts_project\datasets\Lyrics_8842_on_process.csv"
audiopath = r"C:\Users\micha\PycharmProjects\Charts_project\datasets\audio_features_clean_final.csv"

lyrics = pd.read_csv(lyricspath)
audio = pd.read_csv(audiopath)

# %%
lyrics.head()
# Out:
#                       uri  primary_artists featuring_artists      track_name  \
# 0  0gLFuoDun2yzBp67btvQU3  Imagine Dragons               NaN         Wrecked
# 1  0gMywbX34eJ7W8RW7i2Qo3     Aya Nakamura               NaN     Ça fait mal
# 2  0gn0krlJTSSZvnMxh2ITHY          Sofiane               NaN  Mon p'tit loup
# 3  0GN6DWiR9Pf2su3vJF5c0x              SCH               NaN          R.A.C.
# 4  0gn93i7HJt0calph67R5Wu            HUGEL     Amber Van Day            WTF
#
#                                               lyrics langue  \
# 0  Days pass by, and my eyes, they dry, and I thi...     en
# 1  aya nakamura\n eh\nte as tout tente je ai tout...     fr
# 2  je vais te ouvrir les portes les portes de le ...     fr
# 3  ouais ouais\npas deux de mon espece pas trop d...     fr
# 4  Ba-rah, ba-ra-rah, bum-bum, ba-da\nBa-rah, ba-...     en
#
#                                         lyrics_clean  nb_sentences  nb_words  \
# ...

# %% [markdown]
# # analyse audio_features

# %%
audio.columns
# Out:
# Index(['uri', 'artist_id', 'image', 'release_date', 'duration', 'sound',
#        'genre', 'acoustic', 'dance', 'energy', 'instrumental', 'key', 'live',
#        'loud', 'speech', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
px.box(audio, x='genre', y='energy', color='genre', hover_name=audio.index)

# %%
audio.loc[5791]
# Out:
# uri                                          18ddJHQ7CUzNBiy55L0Xjj
# artist_id                                    35R1B97CfrqKFFI3QBkTDx
# image                      ab67616d00001e02d0ee74f4be6b671899a6ce2b
# release_date                                             2021-10-06
# duration                                                     136000
# sound             574c85dadc4ff0abcabfa254cd31b521eadb7a23?cid=8...
# genre                                                           r&b
# acoustic                                                       0.72
# dance                                                         0.437
# energy                                                        0.184
# instrumental                                                0.00253
# key                                                               1
# live                                                          0.113
# loud                                                        -17.667
# ...
